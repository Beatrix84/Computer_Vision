# %% [markdown]
# # Computer Vision avec OpenCV

# %% [markdown]
# Object detection : trouver plusieurs objets dans une scène Object tracking : suivre des objets dans une vidéo Semantic segmentation : attribuer chaque pixel à un objet identifié Instance segmentation : différencier tous les objets dans la scène
#
# * Installez la bibliothèque opencv sous Python (ATTENTION : passez par pip et installez opencv-python) ou essayer import cv2

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#import the libraries
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

#reading the image 

image = cv2.imread('index.png')
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
#plotting the image
plt.imshow(image)

#saving image
cv2.imwrite('test_write.jpg',image)
# Out:
# True

# %% [markdown]
# * Pour les images chargées en couleurs BGR, les convertir en HSV et en YUV

# %% [markdown]
# A color space is a protocol for representing colors in a way that makes them easily reproducible. We know that grayscale images have single pixel values and color images contain 3 values for each pixel – the intensities of the Red, Green and Blue channels.
#
# Most computer vision use cases process images in RGB format. However, applications like video compression and device independent storage – these are heavily dependent on other color spaces, like the Hue-Saturation-Value or HSV color space.
#
# As you understand a RGB image consists of the color intensity of different color channels, i.e. the intensity and color information are mixed in RGB color space but in HSV color space the color and intensity information are separated from each other. This makes HSV color space more robust to lighting changes.

# %%
#converting image to Gray scale 
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
#plotting the grayscale image
plt.imshow(gray_image)

# %%
#converting image to HSV format
hsv_image = cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
#plotting the HSV image
plt.imshow(hsv_image)

# %%
#converting image to YUV format
yuv_image = cv2.cvtColor(image, cv2.COLOR_BGR2YUV)
plt.imshow(yuv_image)

# %% [markdown]
# * Choisir 5 images contenant des flammes (exemples : bougie, feu de cheminée, incendie, etc.) et 5 images sans flammes, les sauver dans un sous-répertoire *images*

# %%
#reading the image 

imagef1 = cv2.imread('./images/f1.jpg')
imagef1 = cv2.cvtColor(imagef1,cv2.COLOR_BGR2RGB)

#plotting the image
plt.imshow(imagef1)

# %%
imagef2 = cv2.imread('./images/f2.jpg')
imagef2 = cv2.cvtColor(imagef2,cv2.COLOR_BGR2RGB)
plt.imshow(imagef2)

# %%
imagef3 = cv2.imread('./images/f3.jpg')
imagef3 = cv2.cvtColor(imagef3,cv2.COLOR_BGR2RGB)

plt.imshow(imagef3)

# %%
imagef4 = cv2.imread('./images/f4.jpg')
imagef4 = cv2.cvtColor(imagef4,cv2.COLOR_BGR2RGB)
plt.imshow(imagef4)

# %%
imagef5 = cv2.imread('./images/f5.jpg')
imagef5 = cv2.cvtColor(imagef5,cv2.COLOR_BGR2RGB)
plt.imshow(imagef5)

# %%
imagenf1 = cv2.imread('./images/nf1.jpg')
imagenf1 = cv2.cvtColor(imagenf1,cv2.COLOR_BGR2RGB)
plt.imshow(imagenf1)

# %%
imagenf2 = cv2.imread('./images/nf2.jpg')
imagenf2 = cv2.cvtColor(imagenf2,cv2.COLOR_BGR2RGB)
plt.imshow(imagenf2)

# %%
imagenf3 = cv2.imread('./images/nf3.jpg')
imagenf3 = cv2.cvtColor(imagenf3,cv2.COLOR_BGR2RGB)
plt.imshow(imagenf3)

# %%
imagenf4 = cv2.imread('./images/nf4.jpg')
imagenf4 = cv2.cvtColor(imagenf4,cv2.COLOR_BGR2RGB)
plt.imshow(imagenf4)

# %%
imagenf5 = cv2.imread('./images/nf5.jpg')
imagenf5 = cv2.cvtColor(imagenf5,cv2.COLOR_BGR2RGB)
plt.imshow(imagenf5)

# %% [markdown]
# * En utilisant la bibliothèque python *glob*, appliquer une fonction de changement de taille d'image d'opencv à toutes les images précédentes et sauvegarder les images avec leur nouvelle taille dans le répertoire images avec un suffixe "_resized" et dans un encodage de votre choix (exemples : jpg, png, etc.). La fonction pourra soit réduire la taille en pourcentage, soit réduire indépendamment hauteur et largeur de l'image

# %%
import glob

images = glob.glob('images/*.jpg')
images
# Out:
# ['images/f1.jpg',
#  'images/f2.jpg',
#  'images/f3.jpg',
#  'images/f4.jpg',
#  'images/f5.jpg',
#  'images/nf1.jpg',
#  'images/nf2.jpg',
#  'images/nf3.jpg',
#  'images/nf4.jpg',
#  'images/nf5.jpg']

# %%
imagenf5 = cv2.imread('./images/nf5.jpg')

#percent by which the image is resized
scale_percent = 50

#calculate the 50 percent of original dimensions
width = int(imagenf5.shape[1] * scale_percent / 100)
height = int(imagenf5.shape[0] * scale_percent / 100)

# dsize
dsize = (width, height)

# resize image
resized = cv2.resize(imagenf5, dsize)
plt.imshow(resized)

#saving image
cv2.imwrite('./images/imagenf5_resized.jpg',resized)

print('Original Dimensions : ',imagenf5.shape)
print('Resized Dimensions : ',resized.shape)
# Out:
# Original Dimensions :  (1100, 1980, 3)
# Resized Dimensions :  (550, 990, 3)

# %%
pip install cvlib
# Out:
# ...
#      |████████████████████████████████| 10.0MB 1.5MB/s eta 0:00:01   |█████████████████▊              | 5.6MB 1.5MB/s eta 0:00:04
# ...
#      |████████████████████████████████| 378kB 23.0MB/s eta 0:00:01
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.2-cp37-none-any.whl size=10043360 sha256=c0b21c85245b90578fcf209cac7c691f5a61473e7ef8ee2ca977de18609701b6
#   Stored in directory: /root/.cache/pip/wheels/22/b7/0f/8d3ee1bf6f30d408e11250bd4d0a8270ffe22fb7b54a987380
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-cp37-none-any.whl size=12073 sha256=129cdc67ff0afd331879028989556c8b1309c18e7be6ce533e8dce44fe3c94cf
#   Stored in directory: /root/.cache/pip/wheels/c0/e9/6b/ea01090205e285175842339aa3b491adeb4015206cda272ff0
# ...
#   Created wheel for imutils: filename=imutils-0.5.3-cp37-none-any.whl size=25850 sha256=a9c25e56a2973f1eb03d0c491f14b1b3b6c8f98e8238ba1a997a5e3755d575ea
#   Stored in directory: /root/.cache/pip/wheels/16/84/1f/bf88641293cda2c8be81a5c4b8ca973dd9125a6dc3767417fd
# ...

# %%
pip install opencv-python tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox

# %%
imagef1 = cv2.imread('./images/f1.jpg')
bbox, label, conf = cv.detect_common_objects(imagef1)
output_image = draw_bbox(imagef1, bbox, label, conf)
plt.imshow(output_image)
plt.show()
# Out:
# ...
#   0% |                                                                        |
# ...
#  99% |####################################################################### |
# ...
# 100% |                                                                        |

# %% [markdown]
# * Réfléchir à comment utiliser les espaces de couleur pour segmenter les images contenant des flammes pour isoler les zones contenant les flammes

# %% [markdown]
# * Fabriquer des images binaires à partir de la segmentation précédente

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread('./images/f1.jpg')
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
ret, thresh = cv.threshold(gray,0,255,cv.THRESH_BINARY_INV+cv.THRESH_OTSU)
plt.imshow(thresh)

# %% [markdown]
# - Récupérer une vidéo contenant des flammes
# - Charger la vidéo dans opencv et la faire jouer dans une fenêtre
# - Appliquer la segmentation binaire précédente à chaque frame et afficher la vidéo correspondante

# %%
import cv2
import numpy as np
 
#video_file = "video_1.mp4"
video = cv2.VideoCapture('./images/fire2LD.mp4')
